# %% [markdown]
# # Experiments1

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from utils_dagm import RemodeNanInstances
from utils_dagm import LoadDataEvaluation
from sklearn.preprocessing import normalize

# %%
InstanceType = 'SISL'
LabelType = 'ALL'
defect = 'AB'

# %% [markdown]
# ### Class 1

# %%
ClassNumber = 1
X_sisl,Y_sisl = LoadDataEvaluation(LabelType,defect,ClassNumber,InstanceType)
#remove rows with nan columns 
nanrows = np.unique(np.where(np.isnan(X_sisl))[0])
X_sisl = np.delete(X_sisl, nanrows, 0)
Y_sisl = np.delete(Y_sisl, nanrows, 0)

#Normalize 
X_sisl = normalize(X_sisl,norm = 'l2',axis=0)

#PCA
pca = PCA(n_components=2)
X2 = pca.fit_transform(X_sisl)
plt.scatter(X2[:, 0], X2[:, 1], cmap=plt.cm.Spectral,c=Y_sisl)
plt.show()

# %% [markdown]
# ### Class 2

# %%
ClassNumber = 2
X_sisl,Y_sisl = LoadDataEvaluation(LabelType,defect,ClassNumber,InstanceType)
#remove rows with nan columns 
nanrows = np.unique(np.where(np.isnan(X_sisl))[0])
X_sisl = np.delete(X_sisl, nanrows, 0)
Y_sisl = np.delete(Y_sisl, nanrows, 0)

#Normalize 
X_sisl = normalize(X_sisl,norm = 'l2',axis=0)

#PCA
pca = PCA(n_components=2)
X2 = pca.fit_transform(X_sisl)
plt.scatter(X2[:, 0], X2[:, 1], cmap=plt.cm.Spectral,c=Y_sisl)
plt.show()

# %% [markdown]
# ### Class 3

# %%
ClassNumber = 3
X_sisl,Y_sisl = LoadDataEvaluation(LabelType,defect,ClassNumber,InstanceType)
#remove rows with nan columns 
nanrows = np.unique(np.where(np.isnan(X_sisl))[0])
X_sisl = np.delete(X_sisl, nanrows, 0)
Y_sisl = np.delete(Y_sisl, nanrows, 0)

#Normalize 
X_sisl = normalize(X_sisl,norm = 'l2',axis=0)

#PCA
pca = PCA(n_components=2)
X2 = pca.fit_transform(X_sisl)
plt.scatter(X2[:, 0], X2[:, 1], cmap=plt.cm.Spectral,c=Y_sisl)
plt.show()

# %% [markdown]
# ### Class 4

# %%
ClassNumber = 4
X_sisl,Y_sisl = LoadDataEvaluation(LabelType,defect,ClassNumber,InstanceType)
#remove rows with nan columns 
nanrows = np.unique(np.where(np.isnan(X_sisl))[0])
X_sisl = np.delete(X_sisl, nanrows, 0)
Y_sisl = np.delete(Y_sisl, nanrows, 0)

#Normalize 
X_sisl = normalize(X_sisl,norm = 'l2',axis=0)

#PCA
pca = PCA(n_components=2)
X2 = pca.fit_transform(X_sisl)
plt.scatter(X2[:, 0], X2[:, 1], cmap=plt.cm.Spectral,c=Y_sisl)
plt.show()

# %% [markdown]
# ### Class 5

# %%
ClassNumber = 5
X_sisl,Y_sisl = LoadDataEvaluation(LabelType,defect,ClassNumber,InstanceType)
#remove rows with nan columns 
nanrows = np.unique(np.where(np.isnan(X_sisl))[0])
X_sisl = np.delete(X_sisl, nanrows, 0)
Y_sisl = np.delete(Y_sisl, nanrows, 0)

#Normalize 
X_sisl = normalize(X_sisl,norm = 'l2',axis=0)

#PCA
pca = PCA(n_components=2)
X2 = pca.fit_transform(X_sisl)
plt.scatter(X2[:, 0], X2[:, 1], cmap=plt.cm.Spectral,c=Y_sisl)
plt.show()
